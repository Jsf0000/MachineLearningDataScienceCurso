# %% [markdown]
# # Jason Solano Fonseca

# %% [markdown]
# # Como importar Pandas

# %% [markdown]
# Tambien utilizamos el numpy una libreria muy utilizada en data science

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Como Cargar un archivo

# %% [markdown]
# Se Puede cargar diferentes tipos de archivo por ejemplo .csv o .xlsx.
#
# Tambien se pueden leer archivos en .json

# %%
# leer csv
datasetCSV = pd.read_csv('https://raw.githubusercontent.com/fmezacr/DataScienceTEC/master/Clase2/pima-indians-diabetes.csv')
# leer xlsx
datasetXLSX = pd.read_excel('https://sds-platform-private.s3-us-east-2.amazonaws.com/uploads/P1-OfficeSupplies.xlsx')
# leer json
datasetJson = pd.read_json('https://raw.githubusercontent.com/jdorfman/awesome-json-datasets/master/package.json')

# %% [markdown]
# # Seguiremos con el datasetCSV

# %% [markdown]
# Formas de leer un dataset

# %%
datasetCSV
# Out:
#       6  148  72  35    0  33.6  0.627  50  1
# 0     1   85  66  29    0  26.6  0.351  31  0
# 1     8  183  64   0    0  23.3  0.672  32  1
# 2     1   89  66  23   94  28.1  0.167  21  0
# 3     0  137  40  35  168  43.1  2.288  33  1
# 4     5  116  74   0    0  25.6  0.201  30  0
# 5     3   78  50  32   88  31.0  0.248  26  1
# 6    10  115   0   0    0  35.3  0.134  29  0
# 7     2  197  70  45  543  30.5  0.158  53  1
# 8     8  125  96   0    0   0.0  0.232  54  1
# 9     4  110  92   0    0  37.6  0.191  30  0
# 10   10  168  74   0    0  38.0  0.537  34  1
# 11   10  139  80   0    0  27.1  1.441  57  0
# 12    1  189  60  23  846  30.1  0.398  59  1
# 13    5  166  72  19  175  25.8  0.587  51  1
# 14    7  100   0   0    0  30.0  0.484  32  1
# 15    0  118  84  47  230  45.8  0.551  31  1
# 16    7  107  74   0    0  29.6  0.254  31  1
# 17    1  103  30  38   83  43.3  0.183  33  0
# 18    1  115  70  30   96  34.6  0.529  32  1
# ...

# %% [markdown]
# Evitando los encabezados e indices

# %%
datasetCSV = pd.read_csv('https://raw.githubusercontent.com/fmezacr/DataScienceTEC/master/Clase2/pima-indians-diabetes.csv',header=None)
datasetCSV
# Out:
#       0    1   2   3    4     5      6   7  8
# 0     6  148  72  35    0  33.6  0.627  50  1
# 1     1   85  66  29    0  26.6  0.351  31  0
# 2     8  183  64   0    0  23.3  0.672  32  1
# 3     1   89  66  23   94  28.1  0.167  21  0
# 4     0  137  40  35  168  43.1  2.288  33  1
# 5     5  116  74   0    0  25.6  0.201  30  0
# 6     3   78  50  32   88  31.0  0.248  26  1
# 7    10  115   0   0    0  35.3  0.134  29  0
# 8     2  197  70  45  543  30.5  0.158  53  1
# 9     8  125  96   0    0   0.0  0.232  54  1
# 10    4  110  92   0    0  37.6  0.191  30  0
# 11   10  168  74   0    0  38.0  0.537  34  1
# 12   10  139  80   0    0  27.1  1.441  57  0
# 13    1  189  60  23  846  30.1  0.398  59  1
# 14    5  166  72  19  175  25.8  0.587  51  1
# 15    7  100   0   0    0  30.0  0.484  32  1
# 16    0  118  84  47  230  45.8  0.551  31  1
# 17    7  107  74   0    0  29.6  0.254  31  1
# 18    1  103  30  38   83  43.3  0.183  33  0
# ...

# %% [markdown]
# Pasar un dataset a matrix de numpy

# %%
matrix = datasetCSV.as_matrix()
matrix
# Out:
# /anaconda3/envs/py3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %% [markdown]
# Obtener los primeros y ultimos elementos
#
# Tambien Aplicable para cada columna

# %%
datasetCSV.head(5)
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
datasetCSV.tail(5)
# Out:
#       0    1   2   3    4     5      6   7  8
# 763  10  101  76  48  180  32.9  0.171  63  0
# 764   2  122  70  27    0  36.8  0.340  27  0
# 765   5  121  72  23  112  26.2  0.245  30  0
# 766   1  126  60   0    0  30.1  0.349  47  1
# 767   1   93  70  31    0  30.4  0.315  23  0

# %% [markdown]
# Descripcion de el data set

# %%
datasetCSV.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#                 6           7           8
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %% [markdown]
# Acceder a cada columna y valores

# %%
datasetCSV[0]
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
# 5       5
# 6       3
# 7      10
# 8       2
# 9       8
# 10      4
# 11     10
# 12     10
# 13      1
# 14      5
# 15      7
# 16      0
# 17      7
# 18      1
# 19      1
# 20      3
# 21      8
# 22      7
# 23      9
# 24     11
# 25     10
# 26      7
# 27      1
# 28     13
# 29      5
#        ..
# 738     2
# 739     1
# 740    11
# 741     3
# 742     1
# 743     9
# 744    13
# 745    12
# 746     1
# 747     1
# 748     3
# 749     6
# 750     4
# 751     1
# 752     3
# 753     0
# 754     8
# 755     1
# 756     7
# 757     0
# 758     1
# 759     6
# 760     2
# 761     9
# 762     9
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: 0, Length: 768, dtype: int64

# %%
datasetCSV[0][0]
# Out:
# 6

# %%
datasetCSV[0][0] = 1
# Out:
# /anaconda3/envs/py3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
datasetCSV.head(1)
# Out:
#    0    1   2   3  4     5      6   7  8
# 0  1  148  72  35  0  33.6  0.627  50  1

# %% [markdown]
# Acceder a una fila

# %%
datasetCSV.iloc[0]
# Out:
# 0      1.000
# 1    148.000
# 2     72.000
# 3     35.000
# 4      0.000
# 5     33.600
# 6      0.627
# 7     50.000
# 8      1.000
# Name: 0, dtype: float64

# %%
datasetCSV.iloc[0,:]
# Out:
# 0      1.000
# 1    148.000
# 2     72.000
# 3     35.000
# 4      0.000
# 5     33.600
# 6      0.627
# 7     50.000
# 8      1.000
# Name: 0, dtype: float64

# %%
datasetCSV.iloc[:,0]
# Out:
# 0       1
# 1       1
# 2       8
# 3       1
# 4       0
# 5       5
# 6       3
# 7      10
# 8       2
# 9       8
# 10      4
# 11     10
# 12     10
# 13      1
# 14      5
# 15      7
# 16      0
# 17      7
# 18      1
# 19      1
# 20      3
# 21      8
# 22      7
# 23      9
# 24     11
# 25     10
# 26      7
# 27      1
# 28     13
# 29      5
#        ..
# 738     2
# 739     1
# 740    11
# 741     3
# 742     1
# 743     9
# 744    13
# 745    12
# 746     1
# 747     1
# 748     3
# 749     6
# 750     4
# 751     1
# 752     3
# 753     0
# 754     8
# 755     1
# 756     7
# 757     0
# 758     1
# 759     6
# 760     2
# 761     9
# 762     9
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: 0, Length: 768, dtype: int64

# %% [markdown]
# Renombrar columnas

# %%
datasetCSV = pd.read_csv('https://raw.githubusercontent.com/fmezacr/DataScienceTEC/master/Clase2/pima-indians-diabetes.csv')

# %%
datasetCSV.shape
# Out:
# (767, 9)

# %%
datasetCSV = datasetCSV.rename(columns={'6': 'Veces Embarazada', '148': 'Glucosa','72':'P Sanguinia','35':'G Cutaneos','0':'Insulina','33.6':'M Corporal','0.627':'Herencia','50':'Edad','1':'Resultado'})

# %% [markdown]
# Uso de condicionales

# %%
datasetCSV.loc[(datasetCSV.Edad == 30)]
# Out:
#      Veces Embarazada  Glucosa  P Sanguinia  G Cutaneos  Insulina  M Corporal  \
# 4                   5      116           74           0         0        25.6
# 9                   4      110           92           0         0        37.6
# 51                  5       88           66          21        23        24.4
# 125                 3      120           70          30       135        42.9
# 131                 3      170           64          37       225        34.5
# 255                 3      111           56          39         0        30.1
# 299                 0      167            0           0         0        32.3
# 308                 2      124           68          28       205        32.9
# 315                 3       99           80          11        64        19.3
# 325                 1      122           64          32       156        35.1
# 350                 4      137           84           0         0        31.2
# ...

# %% [markdown]
# Operaciones con dataframe

# %%
datasetCSV.Edad.sum()
# Out:
# 25479

# %%
datasetCSV.Insulina.mean()
# Out:
# 79.90352020860496

# %%
datasetCSV.Glucosa.std()
# Out:
# 31.978468455767796

# %% [markdown]
# Transformar dataframe

# %%
datasetCSV.to_json('dataset.json')
